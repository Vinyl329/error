# %% [markdown]
# <a href="https://colab.research.google.com/github/Vinyl329/error/blob/main/Untitled222.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import plotly
import plotly.graph_objs as go
import plotly.express as px
from plotly.subplots import make_subplots
import seaborn as sns

# %%
df = pd.read_excel('/content/Массив_50м_необработанный.xlsx')

# %%
df
# Out:
#         Unnamed: 0                  sfn_rps  fnum_rps  rs_rn  \
# 0                1  1574914244946829312.rps         1    695
# 1                2  1574914244946829312.rps         1    721
# 2                3  1574914244946829312.rps         1    731
# 3                4  1574914244946829312.rps         1    745
# 4                5  1574914244946829312.rps         1    767
# ...            ...                      ...       ...    ...
# 111910      120484  1572568012760948736.rps         1  15437
# 111911      120485  1572568012760948736.rps         1  15447
# 111912      120486  1572568012760948736.rps         1  15474
# 111913      120487  1572568012760948736.rps         1  15490
# 111914      120488  1572568012760948736.rps         1  15494
#
#                           time            rs_gc  new_ord           dfb  \
# 0      2022-09-26 09:11:56.741         {1664.0}  1950750     51.832233
# 1      2022-09-26 09:12:14.105         {1664.0}  1950800    101.670919
# ...

# %%
df.to_csv('/content/Массив_50м_необработанный.csv')
